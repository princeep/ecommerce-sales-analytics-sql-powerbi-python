# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("C:/Users/Prince '/OneDrive/DA_Project/Ecommerce_Sales_Data_2024_2025.xlsx")
print(data)
# Out:
#       Order ID Order Date  Year Month  Day     Customer Name Region  \
# 0        10147 2024-01-01  2024   Jan    1  Nayantara Kalita   West
# 1        10941 2024-01-01  2024   Jan    1     Indranil Char  South
# 2        11271 2024-01-01  2024   Jan    1      Jayant Dugar  North
# 3        11299 2024-01-01  2024   Jan    1        Ela Wadhwa  South
# 4        12716 2024-01-01  2024   Jan    1      Sana Trivedi  North
# ...        ...        ...   ...   ...  ...               ...    ...
# 4997     10366 2025-10-03  2025   Oct    3        Rasha Sule   West
# 4998     11524 2025-10-03  2025   Oct    3      Pranay Saraf   West
# 4999     12505 2025-10-03  2025   Oct    3        Heer Banik  North
# 5000     11524 2025-10-03  2025   Oct    3      Pranay Saraf   West
# 5001     12505 2025-10-03  2025   Oct    3        Heer Banik  North
#
#                     City     Category   Sub-Category             Product Name  \
# ...

# %%
data.head()
# data.tail()
# Out:
#    Order ID Order Date  Year Month  Day     Customer Name Region  \
# 0     10147 2024-01-01  2024   Jan    1  Nayantara Kalita   West
# 1     10941 2024-01-01  2024   Jan    1     Indranil Char  South
# 2     11271 2024-01-01  2024   Jan    1      Jayant Dugar  North
# 3     11299 2024-01-01  2024   Jan    1        Ela Wadhwa  South
# 4     12716 2024-01-01  2024   Jan    1      Sana Trivedi  North
#
#                  City     Category   Sub-Category            Product Name  \
# 0           Ahmedabad  Electronics     Smartwatch          Smartwatch Eum
# 1          Coimbatore       Sports    Cricket Bat  Cricket Bat Distinctio
# 2             Lucknow    Furniture          Table        Table Laudantium
# 3  Thiruvananthapuram        Books         Comics          Comics Nostrum
# 4               Delhi         Toys  Action Figure    Action Figure Libero
#
#    Quantity  Unit  Price  Total Sales Profit %  Profit Amount Payment Mode
# ...

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       5000 non-null   int64
#  1   Order Date     5000 non-null   datetime64[ns]
#  2   Year           5000 non-null   int64
#  3   Month          5000 non-null   object
#  4   Day            5000 non-null   int64
#  5   Customer Name  5000 non-null   object
#  6   Region         5000 non-null   object
#  7   City           5000 non-null   object
#  8   Category       5000 non-null   object
#  9   Sub-Category   5000 non-null   object
#  10  Product Name   5000 non-null   object
#  11  Quantity       5000 non-null   int64
#  12  Unit  Price    5000 non-null   int64
#  13  Total Sales    5000 non-null   int64
#  14  Profit %       5000 non-null   object
#  15  Profit Amount  5000 non-null   float64
#  16  Payment Mode   5000 non-null   object
# ...

# %%
data.describe()
# Out:
#            Order ID                  Order Date         Year          Day  \
# count   5000.000000                        5000  5000.000000  5000.000000
# mean   12500.500000  2024-11-13 18:48:40.320000  2024.373400    15.710400
# min    10001.000000         2024-01-01 00:00:00  2024.000000     1.000000
# 25%    11250.750000         2024-07-01 00:00:00  2024.000000     8.000000
# 50%    12500.500000         2024-11-15 00:00:00  2024.000000    16.000000
# 75%    13750.250000         2025-03-30 00:00:00  2025.000000    23.000000
# max    15000.000000         2025-10-03 00:00:00  2025.000000    31.000000
# std     1443.520003                         NaN     0.483755     8.806909
#
#          Quantity   Unit  Price   Total Sales  Profit Amount
# count  5000.00000   5000.000000   5000.000000    5000.000000
# mean      2.99280   8118.152800  24271.239600    3956.102790
# min       1.00000    222.000000    222.000000      11.100000
# ...

# %%
data.dtypes
# Out:
# Order ID                  int64
# Order Date       datetime64[ns]
# Year                      int64
# Month                    object
# Day                       int64
# Customer Name            object
# Region                   object
# City                     object
# Category                 object
# Sub-Category             object
# Product Name             object
# Quantity                  int64
# Unit  Price               int64
# Total Sales               int64
# Profit %                 object
# Profit Amount           float64
# Payment Mode             object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Year             0
# Month            0
# Day              0
# Customer Name    0
# Region           0
# City             0
# Category         0
# Sub-Category     0
# Product Name     0
# Quantity         0
# Unit  Price      0
# Total Sales      0
# Profit %         0
# Profit Amount    0
# Payment Mode     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.drop_duplicates()

# %%
data['Payment Mode'].unique()
# Out:
# array(['Net Banking', 'Debit Card', 'COD', 'Credit Card', 'UPI'],
#       dtype=object)

# %%
data.nunique()
# Out:
# Order ID         5000
# Order Date        642
# Year                2
# Month              12
# Day                31
# Customer Name    4844
# Region              4
# City               20
# Category           10
# Sub-Category       50
# Product Name     3835
# Quantity            5
# Unit  Price      2364
# Total Sales      4072
# Profit %            4
# Profit Amount    4072
# Payment Mode        5
# Full name          20
# dtype: int64

# %%
data['Payment Mode'].value_counts()
# Out:
# Payment Mode
# Net Banking    1010
# COD            1005
# Debit Card     1003
# Credit Card     994
# UPI             988
# Name: count, dtype: int64

# %%
data[data['Payment Mode']=='COD']
# Out:
#       Order ID Order Date  Year Month  Day   Customer Name Region  \
# 6        13222 2024-01-01  2024   Jan    1   Kashvi Sekhon   East
# 9        11417 2024-01-02  2024   Jan    2      Jivika Dua   West
# 19       10488 2024-01-04  2024   Jan    4     Ritvik Dara   East
# 28       14781 2024-01-04  2024   Jan    4   Faiyaz Sarraf  South
# 43       10974 2024-01-06  2024   Jan    6    Taran Chahal   West
# ...        ...        ...   ...   ...  ...             ...    ...
# 4980     13581 2025-09-30  2025   Sep   30    Gokul Doctor   West
# 4985     12022 2025-10-01  2025   Oct    1  Samiha Sanghvi   West
# 4987     12548 2025-10-01  2025   Oct    1      Tara Jaggi  South
# 4993     10508 2025-10-02  2025   Oct    2  Amani Sankaran   East
# 4995     12701 2025-10-02  2025   Oct    2     Jayan Handa  North
#
#              City    Category Sub-Category         Product Name  Quantity  \
# 6     Bhubaneswar   Groceries       Spices           Spices Eos         2
# ...

# %%
data.loc[data['Payment Mode']=='COD',['Product Name','City','Total Sales']]
# Out:
#              Product Name         City  Total Sales
# 6              Spices Eos  Bhubaneswar        19264
# 9     Foundation Quisquam         Pune        38904
# 19                Lamp At      Kolkata         8516
# 28              Doll Enim      Chennai        32832
# 43       Wall Art Dolores         Pune        15186
# ...                   ...          ...          ...
# 4980       Wheat Corporis        Surat        25068
# 4985    Table Perferendis       Mumbai        16412
# 4987      Textbook Veniam    Hyderabad         9235
# 4993   Textbook Doloribus     Guwahati        39868
# 4995         Shampoo Enim   Chandigarh        48535
#
# [1005 rows x 3 columns]

# %%
data.loc[(data.City=='Pune') & (data.Quantity>4)]
# Out:
#       Order ID Order Date  Year Month  Day          Customer Name Region  \
# 71       10020 2024-01-11  2024   Jan   11             Gatik Ravi   West
# 99       10955 2024-01-15  2024   Jan   15          Lavanya Ahuja   West
# 229      13872 2024-02-01  2024   Feb    1            Khushi Seth   West
# 382      10579 2024-02-24  2024   Feb   24             Amira Kala   West
# 384      13405 2024-02-24  2024   Feb   24          Nishith Krish   West
# 414      11676 2024-02-29  2024   Feb   29           Prerak Magar   West
# 498      14773 2024-03-11  2024   Mar   11            Aarna Borde   West
# 513      10074 2024-03-14  2024   Mar   14           Vritika Gade   West
# 557      13852 2024-03-21  2024   Mar   21            Vivaan Kala   West
# 729      13971 2024-04-15  2024   Apr   15              Umang Roy   West
# 778      11771 2024-04-22  2024   Apr   22            Faiyaz Saha   West
# 834      12156 2024-05-01  2024   May    1             Madhav Deo   West
# ...
